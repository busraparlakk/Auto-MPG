# %% [markdown]
# <a href="https://colab.research.google.com/github/busraparlakk/Auto-MPG/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

print("Kütüphaneler yüklendi ✅")
# Out:
# Kütüphaneler yüklendi ✅

# %%
base_path = "/content/drive/MyDrive/food101_project/food-101/food-101/images"

kategoriler = [k for k in os.listdir(base_path)
               if os.path.isdir(f"{base_path}/{k}")]

print(f"Toplam kategori: {len(kategoriler)} ✅")
# Out:
# Toplam kategori: 62 ✅

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

train_generator = train_datagen.flow_from_directory(
    base_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=42
)

val_generator = train_datagen.flow_from_directory(
    base_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=42
)

print(f"Train: {train_generator.samples} fotoğraf")
print(f"Validation: {val_generator.samples} fotoğraf")
print(f"Sınıf sayısı: {train_generator.num_classes}")
# Out:
# Found 48816 images belonging to 62 classes.
# Found 12204 images belonging to 62 classes.
# Train: 48816 fotoğraf
# Validation: 12204 fotoğraf
# Sınıf sayısı: 62

# %%
import os

base_path = "/content/drive/MyDrive/food101_project/food-101/food-101/images"

kategoriler = sorted([k for k in os.listdir(base_path)
               if os.path.isdir(f"{base_path}/{k}")])

print(f"Toplam kategori: {len(kategoriler)}")
print(kategoriler)
# Out:
# Toplam kategori: 62
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich']

# %%
import os

zip_path = "/content/drive/MyDrive/food101_project/food-101.zip"
print(f"Zip boyutu: {os.path.getsize(zip_path) / 1024**3:.2f} GB")
# Out:
# Zip boyutu: 9.38 GB

# %%
import zipfile

zip_path = "/content/drive/MyDrive/food101_project/food-101.zip"
extract_path = "/content/drive/MyDrive/food101_project/"

print("Zip açılıyor, bu biraz sürecek...")

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Tamamlandı ✅")
# Out:
# Zip açılıyor, bu biraz sürecek...
